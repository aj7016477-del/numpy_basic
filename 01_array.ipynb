# %%
# !pip3 install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 1.1 MB/s eta 0:00:0000:0100:010m
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
import numpy as np

# %%
print (np.__version__)
# Out:
# 2.4.0

# %%
## 1. creating arrays

# %%
list1 = [18 , 45 , 10 , 1 , 7 ,33 ]
print(list1)
# Out:
# [18, 45, 10, 1, 7, 33]

# %%
arr_list1 = np.array(list1)      # list to array
print(arr_list1)
# Out:
# [18 45 10  1  7 33]

# %%
list1 = [18 , 5 , 95 ,33 ]
list2 = [10 , 7 , 99 , 17 ]
arr_list1_2 = np.array([list1 , list2])    # 2d array
print(arr_list1_2)
print(type(arr_list1_2))
# Out:
# [[18  5 95 33]
#  [10  7 99 17]]
# <class 'numpy.ndarray'>

# %%
print(arr_list1_2.ndim)       # printing dimention of array output is 2 mens 2d array
# Out:
# 2

# %%
print(type(arr_list1))
# Out:
# <class 'numpy.ndarray'>

# %%
list1 = [18 , 45 , 95 ,33 ]
list2 = [10 , 7 , 99 , 17 ]
list3 = [9 , 11 , 99 , 69 ]
arr_list1_3 = np.array([[list1 , list2 , list3]])  # 3d array
print(arr_list1_3)
# Out:
# [[[18 45 95 33]
#   [10  7 99 17]
#   [ 9 11 99 69]]]

# %%
print(arr_list1_3.ndim)         # printing dimention of array output is 3 mens 3d array
# Out:
# 3
